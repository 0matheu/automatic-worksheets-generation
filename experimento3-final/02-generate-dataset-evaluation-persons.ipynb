# %% [markdown]
# ## This notebook is for generate the structure to be used in the evaluation of the model trained
# - For this evaluation we will use the model *ft:gpt-4.1-2025-04-14:ufcg::CikEQZns* this model was trained with all of the 600 examples of the dataset

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from PIL import Image
import time
import os
import io
import base64
from openai import OpenAI
from dotenv import load_dotenv
import random
random.seed(42)
import json
import pandas as pd
import shutil
import glob
load_dotenv()

client = OpenAI(api_key = os.getenv('OPENAI_API_KEY'))

# %%
parameters = {
    "temperature": [0.5, 0.7],
    "learning goals": [
        {"en": "addition", "pt": "adição"},
        {"en": "subtraction", "pt": "subtração"},
        {"en": "multiplication", "pt": "multiplicação"},
        {"en": "division", "pt": "divisão"},
    ],
    "task": [
        "observe image, write answer",
        "observe image, draw answer",
        "observe images, write answer",
        "observe images, link objects",
    ],
    "themes": [
        {"en": "Circus", "pt": "Circo"},
        {"en": "Camp Forest", "pt": "Acampamento na Floresta"},
        {"en": "Safari", "pt": "Safari"},
        {"en": "Mail", "pt": "Correio"},
        {"en": "Robots and circuits", "pt": "Robôs e circuitos"},
        {"en": "Art studio", "pt": "Estúdio de Arte"},
    ],
}

translation_themes = {
    "fauna and flora": "fauna e flora",
    "toys": "brinquedos",
    "families and numbers": "famílias e números",
    "Cooking Recipe": "Receitas Culinárias",
    "Card Collection": "Coleção de Cartas",
    "Cookies": "Biscoitos",
    "Train Cars on the Tracks": "Vagões de Trem nos Trilhos",
    "Dolls": "Bonecas",
    "airplane": "avião",
    "animals": "animais",
    "Elevator Floor Calculation": "Cálculo de Andares do Elevador",
    "Aquarium": "Aquário",
    "Turtles at the Pond": "Tartarugas no Lago",
    "Pans and Plates in the Kitchen": "Panelas e Pratos na Cozinha",
    "puzzle": "quebra-cabeça",
    "school backpack": "mochila escolar",
}

MODEL = "ft:gpt-4.1-2025-04-14:ufcg::CikEQZns"

# %%
PROMPT_PART_1 = \
f"""Create the complete structure of an **educational worksheet** designed to support student learning.

The worksheet must include a well-organized **visual layout**, using **HTML** to define structural elements and **CSS** to style and position content such as text, images, tables, and any other components that enhance the learning experience.

### 📌 Layout Requirements:

1. **Alignment with the Learning Task**  
   All elements must be positioned and formatted in a way that directly supports the question or task proposed.
   For example: if the student is asked to match images, the images should be arranged separately and spaced appropriately to allow for easy association.

2. **HTML Structure with Descriptive Attributes**  
   Each HTML element must include two key attributes:
   - `alt`: For all images, this attribute must contain a clear, descriptive text that explains the image in a way that allows the student to understand it even without visual access. The description should be contextually accurate and relevant to the task.
   - `exp`: A custom attribute added to each HTML tag that briefly explains the purpose of that element within the worksheet (e.g., `exp="Image illustrating photosynthesis for matching activity"`).

3. **CSS with Explanatory Comments**  
   All CSS used to style or position elements must include **comments above each class or rule**, explaining how the styling contributes to making the worksheet visually engaging, intuitive, and enjoyable for students.

4. **Image Sizing**  
   Images should be sized appropriately to fit within the printable area of the worksheet. They should not exceed the dimensions of the page and should be large enough to clearly represent the content they illustrate.
---

In addition to the HTML and CSS, you must generate a **JSON description** that outlines the worksheet’s structure and purpose. This JSON should contain the following fields:

- `task`: A clear explanation of the learning goal — what the student is expected to learn by completing the worksheet.
- `layout`: A detailed description of how the HTML elements are arranged and used, explaining where each component is placed and why.
- `answer`: A description of what the student must do to complete the worksheet successfully, including the correct answer and any necessary supporting information.

---

### ⚠️ Important Guidelines:

- **Do not generate interactive HTML.** The worksheet is meant to be printed and completed with pen and paper.
- **Ensure image sizes are appropriate** and do not exceed the printable area of the worksheet.
- Always begin by generating the **JSON description**, followed by the corresponding **HTML layout**.
- The elements like images, tables, and text must be arranged in a way that is **visually appealing** and **educationally effective**.
- The elements should be **aligned** and **spaced** to facilitate easy reading and interaction by the student.
- The worksheet should be **creative, engaging, and educational**, strictly adhering to the parameters provided.
- The worksheet should support **playful learning**, encouraging students to interact with the content visually and cognitively.
- The language used in the worksheet must strictly follow the `language` parameter provided.

### 📌 Rules to Follow:

- Do **not** add any text beyond the JSON and the HTML structure of the worksheet.
- Make the worksheet **creative, engaging, and educational**, based strictly on the parameters provided.
- The worksheet should support **playful learning**, encouraging students to interact with the content visually and cognitively.


To create a new worksheet, use the following parameters:
"""

PROMPT_PART_2 = \
"""
Where:

- `level`: the intended school grade or year for the worksheet.
- `subject`: the academic subject to which the worksheet belongs.
- `theme`: the specific topic or concept being addressed.
- `sheet width`: the desired width of the printed worksheet (in pixels or units appropriate for styling).
- `task`: a concise instruction describing what the student must do to complete the worksheet.
- `language`: the language in which the worksheet should be written (e.g., "en" for English, "pt" for Portuguese). This parameter controls all the descriptions, explanations and instructions within the worksheet. respect the language specified.
"""

# %%
def screenshot_completo_via_devtools(html_path, imagem_saida):
    options = Options()
    options.headless = True
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")
    options.add_argument("--hide-scrollbars")
    options.add_argument("--window-size=1920,1080")

    driver = webdriver.Chrome(options=options)
    
    file_url = "file://" + os.path.abspath(html_path)
    driver.get(file_url)

    # Espera carregamento (ajuste se necessário)
    driver.implicitly_wait(2)

    # Garante que está no topo
    driver.execute_script("window.scrollTo(0, 0)")

     # Mede o tamanho real do conteúdo (sem espaço vazio)
    largura = driver.execute_script("return document.documentElement.scrollWidth")
    altura = driver.execute_script("return document.documentElement.scrollHeight")

    # Redimensiona a janela para exatamente esse tamanho
    driver.set_window_size(1000, 1300)

    # Usa DevTools Protocol para capturar a página inteira
    screenshot = driver.execute_cdp_cmd("Page.captureScreenshot", {
        "format": "png",
        "captureBeyondViewport": True,
        "fromSurface": True
    })

    # Decodifica base64 e salva
    with open(imagem_saida, "wb") as f:
        f.write(base64.b64decode(screenshot['data']))

    driver.quit()
    print(f"Imagem salva em: {imagem_saida}")


# screenshot_completo_via_devtools("/home/matheus/Documentos/mestrado-matheus-lisboa/experimento2/runs/2025-07-06 14:08:09.507446.html", "saidase.png")

# %%
def make_request_gpt(parameters, model, temperature=1):

    prompt = f"""
{PROMPT_PART_1}

<parameters>

{PROMPT_PART_2}
"""

    para = ""
    for key, value in parameters.items():
        para += f"{key}: {value}\n"

    prompt = prompt.replace("<parameters>", para)

    completion = client.chat.completions.create(
        model=model,
        temperature=temperature,
        messages=[
            {
                "role": "system",
                "content": "You are an assistant who helps a teacher create activities to help students learn",
            },
            {"role": "user", "content": prompt},
        ],
    )

    output = completion.choices[0].message.to_dict()["content"]

    return output


def extract_html_and_json(output):

    lines = []

    aux = False
    for line in output.split("\n"):
        if line == "<!DOCTYPE html>" or line == "<html>":
            aux = True
        if aux:
            lines.append(line)
        if line == "</html>":
            aux = False

    html_part = "\n".join(lines)
    return html_part


def extract_parameters(example):
    for line in example.split("\n"):
        if "theme:" in line:
            theme = line.replace("theme:", "").strip()
        if "task:" in line:
            task = line.replace("task:", "").strip()

    return {
        "theme": theme,
        "task": task,

    }


def composite_form(parameters):

    aux = """
1 - Discordo totalmente
2 - Discordo
3 - Neutro / Indiferente
4 - Concordo
5 - Concordo totalmente
"""
    aux2 = """
1 - Muito baixa: A atividade é totalmente convencional, previsível e não apresenta elementos novos ou adaptados.
2 - Baixa: A atividade traz pequenas variações, mas ainda segue formatos comuns, com pouca inovação.
3 - Moderada: A atividade apresenta algumas ideias criativas ou adaptações interessantes, mas ainda dentro de um modelo tradicional.
4 - Alta: A atividade demonstra originalidade, com elementos inovadores e estratégias diferenciadas que favorecem o envolvimento dos alunos.
5 - Muito alta: A atividade é excepcionalmente criativa, integrando ideias originais e fora do comum, com grande potencial de engajamento e impacto pedagógico.
"""

    aux3 = """
1 - Muito baixa: O leiaute é convencional, previsível e não traz elementos novos ou diferenciados.
2 - Baixa: O leiaute apresenta pequenas variações, mas ainda segue padrões comuns e pouco inovadores.
3 - Moderada: O leiaute inclui algumas ideias criativas ou adaptações interessantes, embora mantenha um formato tradicional.
4 - Alta: O leiaute demonstra originalidade, com elementos inovadores e bem estruturados para favorecer a aprendizagem.
5 - Muito alta: O leiaute é excepcionalmente criativo, com organização diferenciada, original e altamente envolvente para os alunos.
"""

    aux4 = """
1 - Muito baixa: A forma de resposta é totalmente convencional e não apresenta variações ou elementos criativos.
2 - Baixa: A forma de resposta traz pequenas variações, mas ainda é limitada e pouco inovadora.
3 - Moderada: A forma de resposta apresenta algumas ideias criativas ou alternativas interessantes, mas mantém um padrão tradicional.
4 - Alta: A forma de resposta é original, oferecendo estratégias diferenciadas que estimulam maior envolvimento dos alunos.
5 - Muito alta: A forma de resposta é excepcionalmente criativa, com propostas diversificadas, originais e grande potencial de engajamento e aprendizagem.

"""

    q1 = f"""
A atividade trabalha adequadamente o conceito de {parameters["learning goals"]}?
{aux}
"""

    q2 = f"""
O enunciado da atividade é claro e compreensível?
{aux}
"""

    q3 = f"""
A atividade fornece as informações necessárias para que os alunos consigam resolvê-la corretamente?
{aux}
"""
    q4 = f"""
A atividade está bem contextualizada dentro do tema {parameters["theme"]}?
{aux}
"""
    q5 = f"""
O layout da atividade é bem estruturado e facilita a compreensão?
{aux}
"""
    q6 = f"""
O nível da atividade é adequado para alunos do 2º ano do ensino fundamental?
{aux}
"""

    q7 = f"""
Você utilizaria essa atividade em sala de aula se ela incluísse imagens com as características descritas?
{aux}
"""

    q8 = f"""
Em que medida a contextualização do tema apresenta originalidade e favorece o aprendizado de forma lúdica?
{aux2}
"""

    q9 = f"""
Em que medida o leiaute e a organização da atividade se mostram criativos e contribuem para um aprendizado mais lúdico?
{aux3}
"""

    q10 = f"""
Em que medida a forma de resposta proposta na atividade (escrita, desenho, pintura ou outra) é criativa e estimula a aprendizagem de forma lúdica?
{aux4}
"""

    df = pd.DataFrame(
        [
            [q1, ""],
            [q2, ""],
            [q3, ""],
            [q4, ""],
            [q5, ""],
            [q6, ""],
            [q7, ""],
            [q8, ""],
            [q9, ""],
            [q10, ""],
        ],
        columns=["Pergunta", "Resposta"],
    )

    return df


def generate_dataset_evaluation(path_save, parameters):

    count = 1

    ## gerenate the worksheets from the model
    for temperature in parameters["temperature"]:

        for learning_goal in parameters["learning goals"]:
            for task in parameters["task"]:

                theme = random.choice(parameters["themes"])

                learning_goal_en = learning_goal["en"]
                learning_goal_pt = learning_goal["pt"]

                theme_pt = theme["pt"]
                theme_en = theme["en"]


                if learning_goal_en == "addition" or learning_goal_en == "multiplication":
                    path_save_aux = f"{path_save}/addition-multiplication"
                else:
                    path_save_aux = f"{path_save}/addition-subtraction-division"

                path_save_aux = path_save_aux.replace("//", "/")

                if not os.path.exists(path_save_aux):
                    os.makedirs(path_save_aux)

                shutil.copy("script_verify_answers.py", path_save_aux)


                parameters_activity_en = {
                    "level": "2nd year of fundamental",
                    "learning goals": learning_goal_en,
                    "theme": theme_en,
                    "width-sheet": "800px",
                    "task": task,
                    "language": "pt-br",
                }

                parameters_activity_pt = {
                    "level": "2º ano do ensino fundamental",
                    "learning goals": learning_goal_pt,
                    "theme": theme_pt,
                    "width-sheet": "800px",
                    "task": task,
                    "language": "pt-br",
                }

                print(
                    f"Generating activity {count} with parameters: {learning_goal_en}"
                )

                output = make_request_gpt(parameters_activity_pt, MODEL, temperature)

                html_part = extract_html_and_json(output)

                # save the html to a file at tmp
                html_path = f"tmp/aux.html"
                os.makedirs(os.path.dirname(html_path), exist_ok=True)
                with open(html_path, "w") as f:
                    f.write(html_part)

                # take a screenshot of the html file
                imagem_saida = f"{path_save_aux}/{learning_goal_pt}/{count}/example.png"
                os.makedirs(os.path.dirname(imagem_saida), exist_ok=True)
                screenshot_completo_via_devtools(html_path, imagem_saida)
                print(
                    f"Activity {count} generated and saved to {html_path} and {imagem_saida}"
                )

                # save the parameters
                parameters_activity_path = f"{path_save_aux}/{learning_goal_pt}/{count}/parameters.json"
                os.makedirs(os.path.dirname(parameters_activity_path), exist_ok=True)
                parameters_activity_pt["temperature"] = temperature
                parameters_activity_pt["model"] = MODEL
                with open(parameters_activity_path, "w") as f:
                    json.dump(parameters_activity_pt, f, indent=4)

                # save the form on the same folder
                form = composite_form(parameters_activity_pt)

                form_path = f"{path_save_aux}/{learning_goal_pt}/{count}/form.csv"
                form.to_csv(form_path, index=False)

                count += 1

    # save the worksheets for the control group
    base_path = "/home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/handmade_html_dataset/english/test/"
    for file in glob.glob(f"{base_path}/group-addition/*.html"):
        with open(file, "r") as f:
            data = f.read()

            html_part = extract_html_and_json(data)

            html_path = f"tmp/aux.html"

            os.makedirs(os.path.dirname(html_path), exist_ok=True)
            with open(html_path, "w") as f:
                f.write(html_part)

            path_save_aux = f"{path_save}/addition-multiplication"

            imagem_saida = f"{path_save_aux}/adição/{count}/example.png"

            os.makedirs(os.path.dirname(imagem_saida), exist_ok=True)
            screenshot_completo_via_devtools(html_path, imagem_saida)
            print(
                f"Activity {count} generated and saved to {html_path} and {imagem_saida}"
            )

            parameters_aux = extract_parameters(data)

            parameters_activity_pt = {
                "level": "2º ano do ensino fundamental",
                "learning goals": "adição",
                "theme": translation_themes[parameters_aux["theme"]],
                "width-sheet": "800px",
                "task": parameters_aux["task"],
                "language": "pt-br",
            }

            parameters_activity_path = f"{path_save_aux}/adição/{count}/parameters.json"

            os.makedirs(os.path.dirname(parameters_activity_path), exist_ok=True)
            parameters_activity_pt["temperature"] = "N/A"
            parameters_activity_pt["model"] = "N/A"
            with open(parameters_activity_path, "w") as f:
                json.dump(parameters_activity_pt, f, indent=4)

            form = composite_form(parameters_activity_pt)
            form_path = f"{path_save_aux}/adição/{count}/form.csv"
            form.to_csv(form_path, index=False)
            count += 1
    
    for file in glob.glob(f"{base_path}/group-subtraction/*.html"):
        with open(file, "r") as f:
            data = f.read()

            html_part = extract_html_and_json(data)

            html_path = f"tmp/aux.html"

            os.makedirs(os.path.dirname(html_path), exist_ok=True)
            with open(html_path, "w") as f:
                f.write(html_part)

            path_save_aux = f"{path_save}/addition-subtraction-division"

            imagem_saida = f"{path_save_aux}/adição/{count}/example.png"

            os.makedirs(os.path.dirname(imagem_saida), exist_ok=True)
            screenshot_completo_via_devtools(html_path, imagem_saida)
            print(
                f"Activity {count} generated and saved to {html_path} and {imagem_saida}"
            )

            parameters_aux = extract_parameters(data)

            parameters_activity_pt = {
                "level": "2º ano do ensino fundamental",
                "learning goals": "adição",
                "theme": translation_themes[parameters_aux["theme"]],
                "width-sheet": "800px",
                "task": parameters_aux["task"],
                "language": "pt-br",
            }

            parameters_activity_path = f"{path_save_aux}/adição/{count}/parameters.json"

            os.makedirs(os.path.dirname(parameters_activity_path), exist_ok=True)
            parameters_activity_pt["temperature"] = "N/A"
            parameters_activity_pt["model"] = "N/A"
            with open(parameters_activity_path, "w") as f:
                json.dump(parameters_activity_pt, f, indent=4)

            form = composite_form(parameters_activity_pt)
            form_path = f"{path_save_aux}/adição/{count}/form.csv"
            form.to_csv(form_path, index=False)
            count += 1

# %%
datenow = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
PATH_SAVE = f"/home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/{datenow}/"
generate_dataset_evaluation(PATH_SAVE, parameters)
# Out:
# Generating activity 1 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/1/example.png
# Activity 1 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/1/example.png
# Generating activity 2 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/2/example.png
# Activity 2 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/2/example.png
# Generating activity 3 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/3/example.png
# Activity 3 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/3/example.png
# Generating activity 4 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/4/example.png
# Activity 4 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/4/example.png
# Generating activity 5 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/5/example.png
# Activity 5 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/5/example.png
# Generating activity 6 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/6/example.png
# Activity 6 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/6/example.png
# Generating activity 7 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/7/example.png
# Activity 7 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/7/example.png
# Generating activity 8 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/8/example.png
# Activity 8 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/8/example.png
# Generating activity 9 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/9/example.png
# Activity 9 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/9/example.png
# Generating activity 10 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/10/example.png
# Activity 10 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/10/example.png
# Generating activity 11 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/11/example.png
# Activity 11 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/11/example.png
# Generating activity 12 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/12/example.png
# Activity 12 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/12/example.png
# Generating activity 13 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/13/example.png
# Activity 13 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/13/example.png
# Generating activity 14 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/14/example.png
# Activity 14 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/14/example.png
# Generating activity 15 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/15/example.png
# Activity 15 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/15/example.png
# Generating activity 16 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/16/example.png
# Activity 16 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/16/example.png
# Generating activity 17 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/17/example.png
# Activity 17 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/17/example.png
# Generating activity 18 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/18/example.png
# Activity 18 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/18/example.png
# Generating activity 19 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/19/example.png
# Activity 19 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/19/example.png
# Generating activity 20 with parameters: addition
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/20/example.png
# Activity 20 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/adição/20/example.png
# Generating activity 21 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/21/example.png
# Activity 21 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/21/example.png
# Generating activity 22 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/22/example.png
# Activity 22 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/22/example.png
# Generating activity 23 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/23/example.png
# Activity 23 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/23/example.png
# Generating activity 24 with parameters: subtraction
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/24/example.png
# Activity 24 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/subtração/24/example.png
# Generating activity 25 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/25/example.png
# Activity 25 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/25/example.png
# Generating activity 26 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/26/example.png
# Activity 26 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/26/example.png
# Generating activity 27 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/27/example.png
# Activity 27 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/27/example.png
# Generating activity 28 with parameters: multiplication
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/28/example.png
# Activity 28 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-multiplication/multiplicação/28/example.png
# Generating activity 29 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/29/example.png
# Activity 29 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/29/example.png
# Generating activity 30 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/30/example.png
# Activity 30 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/30/example.png
# Generating activity 31 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/31/example.png
# Activity 31 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/31/example.png
# Generating activity 32 with parameters: division
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/32/example.png
# Activity 32 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31/addition-subtraction-division/divisão/32/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/33/example.png
# Activity 33 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/33/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/34/example.png
# Activity 34 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/34/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/35/example.png
# Activity 35 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/35/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/36/example.png
# Activity 36 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/36/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/37/example.png
# Activity 37 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/37/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/38/example.png
# Activity 38 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/38/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/39/example.png
# Activity 39 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/39/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/40/example.png
# Activity 40 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-multiplication/adição/40/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/41/example.png
# Activity 41 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/41/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/42/example.png
# Activity 42 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/42/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/43/example.png
# Activity 43 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/43/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/44/example.png
# Activity 44 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/44/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/45/example.png
# Activity 45 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/45/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/46/example.png
# Activity 46 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/46/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/47/example.png
# Activity 47 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/47/example.png
# Imagem salva em: /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/48/example.png
# Activity 48 generated and saved to tmp/aux.html and /home/matheus/Documentos/mestrado-matheus-lisboa/experimento3-final/worksheets-generated-evaluation/2025-12-03 15:40:31//addition-subtraction-division/adição/48/example.png

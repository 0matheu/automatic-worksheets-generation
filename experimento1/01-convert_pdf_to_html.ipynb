# %%
# !pip install aspose-words==23.10.0
# !pip install pdftotree
# !pip install PyMuPDF

# %% [markdown]
# ## tentando converter o pdf para um html

# %%
import aspose.words as aw

# %%
doc = aw.Document("data/pdf/SSE_BQ_Matemática_2A_SR.pdf")

# %%
doc.save("data/html/output.html")

# %% [markdown]
# ## tentando extrair o texto e também as imagens
